# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.losses import sparse_categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train = 'dataset/split_random/train/'
val = 'dataset/split_random/val/'

# %%
train_generator = ImageDataGenerator(rescale = 1./255)
train_generator = train_generator.flow_from_directory(train,
                                                     target_size=(300, 300),
                                                     batch_size=32,
                                                     class_mode='sparse')

labels = train_generator.class_indices
# Out:
# Found 7600 images belonging to 5 classes.

# %%
val_generator = ImageDataGenerator(rescale = 1./255)
val_generator = val_generator.flow_from_directory(val,
                                                     target_size=(300, 300),
                                                     batch_size=32,
                                                     class_mode='sparse')

labels = val_generator.class_indices
# Out:
# Found 950 images belonging to 5 classes.

# %%
num_classes = 5

model = Sequential([
  layers.Conv2D(16, 3, padding='same', activation='relu', input_shape = (300, 300, 3)),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 300, 300, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 150, 150, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 150, 150, 32)      4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 75, 75, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 37, 37, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 37, 37, 64)        0
# ...

# %%
model.fit_generator(train_generator, epochs = 100, steps_per_epoch = 7600  / 32, validation_data=val_generator, validation_steps= 950 /32)
# Out:
# WARNING:tensorflow:From <ipython-input-8-66fdb31778e4>:1: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/100
# 238/237 [==============================] - 396s 2s/step - loss: 1.5919 - accuracy: 0.2992 - val_loss: 1.4633 - val_accuracy: 0.3821
# Epoch 2/100
# 238/237 [==============================] - 398s 2s/step - loss: 1.3818 - accuracy: 0.4230 - val_loss: 1.3708 - val_accuracy: 0.4463
# Epoch 3/100
# 238/237 [==============================] - 403s 2s/step - loss: 1.1620 - accuracy: 0.5422 - val_loss: 1.3718 - val_accuracy: 0.4621
# Epoch 4/100
# 238/237 [==============================] - 403s 2s/step - loss: 0.8535 - accuracy: 0.6693 - val_loss: 1.5555 - val_accuracy: 0.4611
# Epoch 5/100
# ...

# %%
model.save('D:/Recycling_Keras/model/model_ver15_dropdown.h5')
