# %%
waste_types = ['glass','metal','paper','plastic','trash']

# %%
from shutil import move
import os

path = 'D:/Recycling_Keras/sample/'
new_path = 'D:/Recycling_Keras/sample_re/'
os.chdir(path)
os.makedirs(new_path, exist_ok=True)

i = 1
for filename in os.listdir():
    print(path+filename, '=>', 'D:/Recycling_Keras/sample_re/' + 'sample'+str(i)+'.jpg')
    move(path+filename, 'D:/Recycling_Keras/sample_re/'+'sample'+str(i)+'.jpg')
    i += 1
# Out:
# D:/Recycling_Keras/sample/KakaoTalk_20210727_174047994.jpg => D:/Recycling_Keras/sample_re/sample1.jpg
# D:/Recycling_Keras/sample/KakaoTalk_20210727_174047994_01.jpg => D:/Recycling_Keras/sample_re/sample2.jpg
# D:/Recycling_Keras/sample/KakaoTalk_20210727_174047994_02.jpg => D:/Recycling_Keras/sample_re/sample3.jpg
# D:/Recycling_Keras/sample/KakaoTalk_20210728_130140643.jpg => D:/Recycling_Keras/sample_re/sample4.jpg
# D:/Recycling_Keras/sample/KakaoTalk_20210728_130140643_01.jpg => D:/Recycling_Keras/sample_re/sample5.jpg
# D:/Recycling_Keras/sample/KakaoTalk_20210728_130140643_02.jpg => D:/Recycling_Keras/sample_re/sample6.jpg
# D:/Recycling_Keras/sample/KakaoTalk_20210728_130140643_03.jpg => D:/Recycling_Keras/sample_re/sample7.jpg
# D:/Recycling_Keras/sample/KakaoTalk_20210728_130140643_04.jpg => D:/Recycling_Keras/sample_re/sample8.jpg
# D:/Recycling_Keras/sample/KakaoTalk_20210728_130140643_05.jpg => D:/Recycling_Keras/sample_re/sample9.jpg
# ...
