# %%
import os

# %%
path = 'D:/Recycling_Keras/dataset/random/trash/'

# %%
os.listdir(path)
# Out:
# ['trash100.jpg',
#  'trash1002.jpg',
#  'trash1004.jpg',
#  'trash1006.jpg',
#  'trash1007.jpg',
#  'trash1010.jpg',
#  'trash1011.jpg',
#  'trash1013.jpg',
#  'trash1015.jpg',
#  'trash102.jpg',
#  'trash1020.jpg',
#  'trash1022.jpg',
#  'trash1023.jpg',
#  'trash1027.jpg',
#  'trash1030.jpg',
#  'trash1032.jpg',
#  'trash1038.jpg',
#  'trash1043.jpg',
#  'trash1045.jpg',
#  'trash105.jpg',
#  'trash1050.jpg',
#  'trash1058.jpg',
#  'trash106.jpg',
#  'trash1061.jpg',
#  'trash1063.jpg',
#  'trash1065.jpg',
#  'trash1066.jpg',
#  'trash1067.jpg',
#  'trash107.jpg',
#  'trash1074.jpg',
#  'trash1077.jpg',
#  'trash1080.jpg',
#  'trash1081.jpg',
#  'trash1082.jpg',
#  'trash1084.jpg',
#  'trash1086.jpg',
#  'trash109.jpg',
#  'trash1090.jpg',
#  'trash1092.jpg',
#  'trash1093.jpg',
#  'trash1099.jpg',
#  'trash1105.jpg',
#  'trash1107.jpg',
#  'trash1111.jpg',
#  'trash1112.jpg',
#  'trash1115.jpg',
#  'trash1117.jpg',
#  'trash1118.jpg',
#  'trash1120.jpg',
#  'trash1123.jpg',
# ...

# %%
import numpy as np
for filename in os.listdir(path):
    check = '.jpg' not in filename
    if check :
        print('this', filename)
