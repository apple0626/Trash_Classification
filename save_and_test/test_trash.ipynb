# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from keras.models import load_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
model = load_model('model/image_size_down.h5')

# %%
class_names = ['glass', 'metal', 'paper', 'plastic', 'trash']

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

test_path = "D:/Recycling_Keras/sample/sample119.jpg"
img = keras.preprocessing.image.load_img(
    test_path, target_size=(150, 150)
)
img_array = image.img_to_array(img, dtype=np.uint8)
img = np.array(img)/255.0
prediction = model.predict(img[np.newaxis, ...])

print('Prob : ', np.max(prediction[0], axis = -1))
predicted_class = class_names[np.argmax(prediction[0], axis = -1)]
print('Classified : ', predicted_class, '\n')

plt.axis('off')
plt.imshow(img.squeeze())
plt.title('loaded image')
# Out:
# Prob :  0.40939325
# Classified :  plastic
# Text(0.5, 1.0, 'loaded image')

# %%
classes = []
probability = []

for i, j in enumerate(prediction[0], 0):
    print(class_names[i]
          .upper(), ':', round(j * 100, 2), '%')
# Out:
# GLASS : 0.02 %
# METAL : 0.0 %
# PAPER : 3.94 %
# PLASTIC : 0.0 %
# TRASH : 96.04 %

# %%
f = open("D:/Recycling_Keras/result.txt", 'w')
f.write(class_names[np.argmax(score)])
f.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-79e1d7b2eca1> in <module>
#       1 f = open("D:/Recycling_Keras/result.txt", 'w')
# ----> 2 f.write(class_names[np.argmax(score)])
#       3 f.close()
#
# NameError: name 'score' is not defined
